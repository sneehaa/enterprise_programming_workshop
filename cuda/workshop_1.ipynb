# %%
# !nvcc --version
# Out:
# zsh:1: command not found: nvcc

# %%
# %pip install nvcc4jupyter
# Out:
# Collecting nvcc4jupyter
#   Downloading nvcc4jupyter-1.2.1-py3-none-any.whl.metadata (5.1 kB)
# Downloading nvcc4jupyter-1.2.1-py3-none-any.whl (10 kB)
# Installing collected packages: nvcc4jupyter
# Successfully installed nvcc4jupyter-1.2.1
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext nvcc4jupyter
# Out:
# Source files will be saved in "/var/folders/gx/2nrmrr3j2r77hyppdhdz7xcw0000gn/T/tmpbh55lz0k".

# %%
# %%writefile cudahelloworld.cu
# #include <stdio.h>
# #include <cuda.h>
# #include <cuda_runtime.h>
#
# __global__ void kernel()
# {
#   printf("Hello world from kernel\n");
# }
# int main()
# {
#   printf("Hello world from host\n");
#   kernel<<<3,1>>>();
#
#   cudaDeviceSynchronize();
#
#   return 0;
# }
# Out:
# Writing cudahelloworld.cu

# %%
# !ls
# Out:
# cudahelloworld.cu cudapi.ipynb      cudaprime.ipynb   workshop_1.ipynb

# %%
# !nvcc cudahelloworld.cu -o cudahelloworld -arch=sm_70
# Out:
# zsh:1: command not found: nvcc

# %%
# !./cudahelloworld
# Out:
# zsh:1: no such file or directory: ./cudahelloworld
